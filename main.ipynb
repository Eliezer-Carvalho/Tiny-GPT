# %% [markdown]
# <h1> 1. Tokenizer </h1>

# %% [markdown]
# <p> Nesta etapa, inserimos o nosso dataset no Algoritmo de Aprendizagem </p>

# %%
from tokenizers import Tokenizer
# Out:
# Running cells with 'env (Python 3.13.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/User/Desktop/Tiny-Transformer/env/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
